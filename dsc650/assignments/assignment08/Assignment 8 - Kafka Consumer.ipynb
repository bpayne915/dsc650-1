# %%
import json

from kafka import KafkaConsumer

# %% [markdown]
# ### Configuration Parameters
#
# > **TODO:** Change the configuration prameters to the appropriate values for your setup.

# %%
config = dict(
    bootstrap_servers=['kafka.kafka.svc.cluster.local:9092'],
    first_name='Barbara',
    last_name='Payne'
)

config['client_id'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)
config['topic_prefix'] = '{}{}'.format(
    config['last_name'], 
    config['first_name']
)

config
# Out:
# {'bootstrap_servers': ['kafka.kafka.svc.cluster.local:9092'],
#  'first_name': 'Barbara',
#  'last_name': 'Payne',
#  'client_id': 'PayneBarbara',
#  'topic_prefix': 'PayneBarbara'}

# %% [markdown]
# Create a consumer without subscribing to any particular topic

# %%
general_consumer = KafkaConsumer(
    bootstrap_servers=config['bootstrap_servers']
)

# %% [markdown]
# List all topics you are currently allowed to view

# %%
general_consumer.topics()
# Out:
# {'AdamCurry-accelerations',
#  'AdamCurry-locations',
#  'AtmadjaRio-accelerations',
#  'AtmadjaRio-locations',
#  'ByardMegan-accelerations',
#  'ByardMegan-locations',
#  'CurryAdam-accelerations',
#  'CurryAdam-locations',
#  'DoeJohn-accelerations',
#  'DoeJohn-locations',
#  'DoeJohn-simple',
#  'DoeagerJohn-accelerations',
#  'DoeagerJohn-locations',
#  'EagerBrian-accelerations',
#  'EagerBrian-locations',
#  'EdmundsEvan-locations',
#  'FoxAndrea-accelerations',
#  'FoxAndrea-locations',
#  'LoydSam-accelerations',
#  'LoydSam-locations',
#  'MalenchikAli-locations',
#  'OkeOsmond-accelerations',
#  'OkeOsmond-locations',
#  'OmprakashSantosh-accelerations',
#  'OmprakashSantosh-locations',
#  'PayneBarbara-accelerations',
#  'PayneBarbara-locations',
#  'SahaDisha-accelerations',
#  'SahaDisha-locations',
#  'SearsSamuel-accelerations',
#  'SearsSamuel-locations',
#  'SuryaBhushan-accelerations',
#  'SuryaBhushan-locations'}

# %% [markdown]
# Close the consumer, waiting indefinitely for any needed cleanup.

# %%
general_consumer.close()

# %%
def create_kafka_consumer(topics, config=config):
    bootstrap_servers = config['bootstrap_servers']
    client_id = config['client_id']
    topic_prefix = config['topic_prefix']    
    topic_list = ['{}-{}'.format(topic_prefix, topic) for topic in topics]
    
    return KafkaConsumer(
        *topic_list,
        client_id=client_id,
        bootstrap_servers=bootstrap_servers,
        auto_offset_reset='earliest',
        enable_auto_commit=False,
        value_deserializer=lambda x: json.loads(x)
    )

consumer = create_kafka_consumer(['locations', 'accelerations'])

# %% [markdown]
# Gets a list of this consumer's current subscriptions

# %%
consumer.subscription()
# Out:
# {'PayneBarbara-accelerations', 'PayneBarbara-locations'}

# %% [markdown]
# The following function prints messages from the current consumer subscriptions. It will continue until manually stopped.

# %%
def print_messages(consumer=consumer):
    try:
        for message in consumer:
                msg_metadata = 'Message metadata: {}:{}:{}'.format(
                    message.topic, message.partition, message.offset
                )

                if message.key is not None:
                    msg_key = message.key.decode('utf-8')
                else:
                    msg_key = ''
                msg_value = json.dumps(message.value, indent=2)
                msg_value = '\n'.join(['  {}'.format(value) for value in msg_value.split('\n')])

                print('Message metadata:')
                print('  Topic: {}'.format(message.topic))
                print('  Partition: {}'.format(message.partition))
                print('  Offset: {}'.format(message.offset))
                print('Message Key: {}'.format(msg_key))
                print('Message Value:')
                print(msg_value)
                print()
    except KeyboardInterrupt:
        print("STOPPING MESSAGE CONSUMER")
        
print_messages()
# Out:
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 0
# Message Key: a7e182d8414946838b534b32c758c794
# Message Value:
#   {
#     "key1": "value1",
#     "key2": "value2"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 1
# Message Key: ce3a825e67834fa89f022c956da4392f
# Message Value:
#   {
#     "key1": "value1",
#     "key2": "value2"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 2
# Message Key: df0e855655794872a19edc7158e94550
# Message Value:
#   {
#     "key1": "value1",
#     "key2": "value2"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 3
# Message Key: f5a4d9f1067e4bac861d539a58b8428f
# Message Value:
#   {
#     "key1": "value1",
#     "key2": "value2"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 4
# Message Key: 6a82e882490b44db8585f64311e4f8e2
# Message Value:
#   {
#     "key1": "value1",
#     "key2": "value2"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 5
# Message Key: 6117b24d0cb6422882c2b5a8cdf6d738
# Message Value:
#   {
#     "index": 1,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320453",
#     "offset": 1.0779125295566454,
#     "course": 158.203125,
#     "latitude": 40.677641336844,
#     "longitude": -73.81793000742218,
#     "geohash": "dr5x2jpkmtcy",
#     "speed": 2.119999885559082,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 6
# Message Key: 20501a39fee54711845c2d01ba922630
# Message Value:
#   {
#     "index": 0,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.76287002542555,
#     "longitude": -73.96194855681718,
#     "geohash": "dr5ruuwscttz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 7
# Message Key: 4f45d2861934418493b8c5f35ccf67b3
# Message Value:
#   {
#     "index": 2,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882583",
#     "offset": 4.5250608865228426,
#     "course": 299.619140625,
#     "latitude": 40.76287038067684,
#     "longitude": -73.96194937863832,
#     "geohash": "dr5ruuwsctv3",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "004.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 8
# Message Key: 7664184351ac464c9edf5894a447fd67
# Message Value:
#   {
#     "index": 3,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320449",
#     "offset": 5.077912529556645,
#     "course": 159.9609375,
#     "latitude": 40.67788281947438,
#     "longitude": -73.81804710260948,
#     "geohash": "dr5x2jpmfffw",
#     "speed": 11.75,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "004.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 9
# Message Key: 1727c5d0456c48b5abb7aad7476e7b94
# Message Value:
#   {
#     "index": 5,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320446",
#     "offset": 8.077912529556645,
#     "course": 159.609375,
#     "latitude": 40.67819106396351,
#     "longitude": -73.81819261244854,
#     "geohash": "dr5x2jppxkqj",
#     "speed": 13.149999618530273,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "007.8"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 10
# Message Key: a277b103e503492088b85faeb81e1c96
# Message Value:
#   {
#     "index": 4,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882579",
#     "offset": 8.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.76286948909357,
#     "longitude": -73.96194731609269,
#     "geohash": "dr5ruuwsctwg",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "007.8"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 11
# Message Key: fff13a14449d4deab27425081d191912
# Message Value:
#   {
#     "index": 7,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320443",
#     "offset": 11.077912529556645,
#     "course": 159.609375,
#     "latitude": 40.678531159684695,
#     "longitude": -73.81836075342616,
#     "geohash": "dr5x2jr1eebd",
#     "speed": 13.800000190734863,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 12
# Message Key: d4fbbdfdb8214c19a5d2a589355b4416
# Message Value:
#   {
#     "index": 6,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882576",
#     "offset": 11.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.762862338920996,
#     "longitude": -73.96193077522916,
#     "geohash": "dr5ruuwsfh71",
#     "speed": 1.5099999904632568,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 13
# Message Key: b2283d462d3a45f09a55053ff9a8a5d5
# Message Value:
#   {
#     "index": 8,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.077912529556645,
#     "course": 161.015625,
#     "latitude": 40.678637903221585,
#     "longitude": -73.81842395297608,
#     "geohash": "dr5x2jr44p9x",
#     "speed": 14.210000038146973,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 14
# Message Key: d4c11d1f1c2a4711b1f4506c848b1180
# Message Value:
#   {
#     "index": 10,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320439",
#     "offset": 15.077912529556645,
#     "course": 161.3671875,
#     "latitude": 40.67896198950771,
#     "longitude": -73.8185656909587,
#     "geohash": "dr5x2jqunspu",
#     "speed": 10.90999984741211,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "014.9"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 15
# Message Key: cd24f8d38f8a404da7a36c10404bd341
# Message Value:
#   {
#     "index": 9,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882572",
#     "offset": 15.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.76281643742535,
#     "longitude": -73.96182458892834,
#     "geohash": "dr5ruuwssedr",
#     "speed": 4.46999979019165,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "014.9"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 16
# Message Key: fbe341d96de746cd947e7ed098c65bf5
# Message Value:
#   {
#     "index": 12,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320436",
#     "offset": 18.077912529556645,
#     "course": 153.28125,
#     "latitude": 40.679180002809204,
#     "longitude": -73.81866442977807,
#     "geohash": "dr5x2jqvkky2",
#     "speed": 5.340000152587891,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "017.9"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 17
# Message Key: 43e7c2f21968424b9ac79db89c45e1dd
# Message Value:
#   {
#     "index": 11,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882569",
#     "offset": 18.52506088652284,
#     "course": 299.619140625,
#     "latitude": 40.762750198059244,
#     "longitude": -73.96167135398129,
#     "geohash": "dr5ruuwu0pks",
#     "speed": 4.039999961853027,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "017.9"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 18
# Message Key: f5471e60275244c2ab13b7acdd8a8a6a
# Message Value:
#   {
#     "index": 13,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882566",
#     "offset": 21.52506088652284,
#     "course": 28.2119197845459,
#     "latitude": 40.76254921716176,
#     "longitude": -73.961669236952,
#     "geohash": "dr5ruuwg01yj",
#     "speed": 10.149999618530273,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "021.3"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 19
# Message Key: 33ab10da010c4d2a954e37f1220df27a
# Message Value:
#   {
#     "index": 15,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320432",
#     "offset": 22.077912529556645,
#     "course": 70.3125,
#     "latitude": 40.67922610327665,
#     "longitude": -73.81890138618073,
#     "geohash": "dr5x2jqtwvme",
#     "speed": 10.59000015258789,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "021.3"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 20
# Message Key: 4e80771612ca4edda91131708f324fe7
# Message Value:
#   {
#     "index": 14,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882565",
#     "offset": 22.52506088652284,
#     "course": 28.2119197845459,
#     "latitude": 40.76246101371128,
#     "longitude": -73.96173146890654,
#     "geohash": "dr5ruuwdw9rz",
#     "speed": 12.359999656677246,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "021.3"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 21
# Message Key: 3fb2f7c3e334470aa8476b5dd316efb2
# Message Value:
#   {
#     "index": 16,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882561",
#     "offset": 26.52506088652284,
#     "course": 28.47345733642578,
#     "latitude": 40.76203460826988,
#     "longitude": -73.96203257299638,
#     "geohash": "dr5ruuw2p9zr",
#     "speed": 11.359999656677246,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "026.1"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 22
# Message Key: caaf84470dd145d195235476bc129f81
# Message Value:
#   {
#     "index": 17,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320427",
#     "offset": 27.077912529556645,
#     "course": 69.609375,
#     "latitude": 40.6790446769825,
#     "longitude": -73.81956908858737,
#     "geohash": "dr5x2jqhx7e9",
#     "speed": 12.069999694824219,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "026.1"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 23
# Message Key: d52d3511cf9d43cc816310b74e95bf1d
# Message Value:
#   {
#     "index": 20,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882557",
#     "offset": 30.52506088652284,
#     "course": 27.9405517578125,
#     "latitude": 40.761732040212436,
#     "longitude": -73.9622444848301,
#     "geohash": "dr5ruuqq6c96",
#     "speed": 7.849999904632568,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "030.4"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 24
# Message Key: bea03ced882b4d65a3379a30efb423b1
# Message Value:
#   {
#     "index": 18,
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366772",
#     "offset": 31.02312381072749,
#     "course": 81.5625,
#     "latitude": 40.62653339471726,
#     "longitude": -73.97117282270824,
#     "geohash": "dr5rhezfdwxz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov",
#     "t": "030.4"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 25
# Message Key: f42ff17a3e8e4c9fb46ecb2b0c3436c3
# Message Value:
#   {
#     "index": 22,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320423",
#     "offset": 31.077912529556645,
#     "course": 67.5,
#     "latitude": 40.67889422182057,
#     "longitude": -73.82009002386948,
#     "geohash": "dr5x2jmgepx2",
#     "speed": 11.09000015258789,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "030.4"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 26
# Message Key: e0885fad77e745ceafbbe0a0925ed9e2
# Message Value:
#   {
#     "index": 21,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882556",
#     "offset": 31.52506088652284,
#     "course": 28.199682235717773,
#     "latitude": 40.76166818421924,
#     "longitude": -73.96228934322505,
#     "geohash": "dr5ruuqmctxv",
#     "speed": 7.460000038146973,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "030.4"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 27
# Message Key: 1d47fa144e3f47199681fa2eaa3f6b6b
# Message Value:
#   {
#     "index": 19,
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366771",
#     "offset": 32.02312381072749,
#     "course": 81.5625,
#     "latitude": 40.62653339471726,
#     "longitude": -73.97117282270824,
#     "geohash": "dr5rhezfdwxz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov",
#     "t": "030.4"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 28
# Message Key: f6b56202f1b547e9a4a1e3c00ee542f4
# Message Value:
#   {
#     "index": 23,
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366769",
#     "offset": 34.02312381072749,
#     "course": 81.2109375,
#     "latitude": 40.62653339471726,
#     "longitude": -73.97117282270824,
#     "geohash": "dr5rhezfdwxz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 29
# Message Key: 11ce88a84bc64fbfbd8c781b2c0c01a4
# Message Value:
#   {
#     "index": 29,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320420",
#     "offset": 34.07791252955665,
#     "course": 76.640625,
#     "latitude": 40.67880348771874,
#     "longitude": -73.82039755589685,
#     "geohash": "dr5x2jmehn9f",
#     "speed": 6.349999904632568,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 30
# Message Key: 76dbe20d045d4915b1feb9d4ca0a28aa
# Message Value:
#   {
#     "index": 27,
#     "id": "097ec0c2d59a23b76b4942bd8d9a7a77",
#     "ride_id": "9cd83b5a569a73d2e596888b6a6ad6ad",
#     "uuid": "a8fab740fe074ef1acc7d4c940398ce8",
#     "timestamp": "1970-01-01 00:25:04.070080",
#     "offset": 34.16329633059419,
#     "course": 316.7578125,
#     "latitude": 37.52660305708416,
#     "longitude": -122.27024087693754,
#     "geohash": "9q9j3xt82cu6",
#     "speed": 26.6299991607666,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "65c58848-8a31-4b1c-bfef-8643378fec25.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 31
# Message Key: 8ecfc2234df04cee840cf0d4a95668e7
# Message Value:
#   {
#     "index": 25,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882553",
#     "offset": 34.525060886522844,
#     "course": 28.199682235717773,
#     "latitude": 40.761512977133634,
#     "longitude": -73.96239878473625,
#     "geohash": "dr5ruuqjp0y0",
#     "speed": 5.960000038146973,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 32
# Message Key: 06aafa1bce3b4b2292683b5fc3797311
# Message Value:
#   {
#     "index": 24,
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366768",
#     "offset": 35.02312381072749,
#     "course": 81.2109375,
#     "latitude": 40.62653339471726,
#     "longitude": -73.97117282270824,
#     "geohash": "dr5rhezfdwxz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 33
# Message Key: 7595be7767a346328c86f7f0dd1f17c1
# Message Value:
#   {
#     "index": 30,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320419",
#     "offset": 35.07791252955665,
#     "course": 103.0078125,
#     "latitude": 40.678800176866986,
#     "longitude": -73.82046670659801,
#     "geohash": "dr5x2jme4myr",
#     "speed": 4.820000171661377,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 34
# Message Key: cf92334ec42c4cf0a1d1c528fb20960d
# Message Value:
#   {
#     "index": 26,
#     "id": "723d9d0fa092b5ca1ffce252012836de",
#     "ride_id": "4f9ca8ae06a03858267820b3ad458fce",
#     "uuid": "459eeb9143d04df3b27397678047be20",
#     "timestamp": "1970-01-01 00:25:04.355841",
#     "offset": 35.14024503805739,
#     "course": 112.8515625,
#     "latitude": 40.87365692019544,
#     "longitude": -73.85491926229918,
#     "geohash": "dr72x2u6r9us",
#     "speed": 12.640000343322754,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "78665bfb-b7d8-464a-a840-8a967d44e187.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 35
# Message Key: 0f50c05611b24bcfa93b1a497f23847b
# Message Value:
#   {
#     "index": 28,
#     "id": "097ec0c2d59a23b76b4942bd8d9a7a77",
#     "ride_id": "9cd83b5a569a73d2e596888b6a6ad6ad",
#     "uuid": "a8fab740fe074ef1acc7d4c940398ce8",
#     "timestamp": "1970-01-01 00:25:04.070079",
#     "offset": 35.16329633059419,
#     "course": 316.7578125,
#     "latitude": 37.526432317716555,
#     "longitude": -122.2700351850337,
#     "geohash": "9q9j3xmxmdj8",
#     "speed": 26.799999237060547,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "65c58848-8a31-4b1c-bfef-8643378fec25.mov",
#     "t": "033.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 36
# Message Key: ba9765bfd13d486293757d8fcb65bbd0
# Message Value:
#   {
#     "index": 31,
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366765",
#     "offset": 38.02312381072749,
#     "course": 81.2109375,
#     "latitude": 40.62653339471726,
#     "longitude": -73.97117282270824,
#     "geohash": "dr5rhezfdwxz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov",
#     "t": "037.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 37
# Message Key: 5619b559e1e5411285af1b10b8e297b6
# Message Value:
#   {
#     "index": 36,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320416",
#     "offset": 38.07791252955665,
#     "course": 158.90625,
#     "latitude": 40.678862412498034,
#     "longitude": -73.82057458169183,
#     "geohash": "dr5x2jm7xctf",
#     "speed": 3.450000047683716,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "037.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 38
# Message Key: 1283aea226ea4c9d87d366ffdac77ede
# Message Value:
#   {
#     "index": 33,
#     "id": "723d9d0fa092b5ca1ffce252012836de",
#     "ride_id": "4f9ca8ae06a03858267820b3ad458fce",
#     "uuid": "459eeb9143d04df3b27397678047be20",
#     "timestamp": "1970-01-01 00:25:04.355838",
#     "offset": 38.14024503805739,
#     "course": 111.4453125,
#     "latitude": 40.87378105618141,
#     "longitude": -73.85532821535492,
#     "geohash": "dr72x2u5n15c",
#     "speed": 12.130000114440918,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "78665bfb-b7d8-464a-a840-8a967d44e187.mov",
#     "t": "037.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 39
# Message Key: dd2733fbf51a470fb9bb4259af35832a
# Message Value:
#   {
#     "index": 34,
#     "id": "097ec0c2d59a23b76b4942bd8d9a7a77",
#     "ride_id": "9cd83b5a569a73d2e596888b6a6ad6ad",
#     "uuid": "a8fab740fe074ef1acc7d4c940398ce8",
#     "timestamp": "1970-01-01 00:25:04.070076",
#     "offset": 38.16329633059419,
#     "course": 317.4609375,
#     "latitude": 37.52591209489621,
#     "longitude": -122.26942481484475,
#     "geohash": "9q9j3xqh7chc",
#     "speed": 26.040000915527344,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "65c58848-8a31-4b1c-bfef-8643378fec25.mov",
#     "t": "037.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 40
# Message Key: 988dd951b60d4ae7932e7117ca899e86
# Message Value:
#   {
#     "index": 32,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882549",
#     "offset": 38.525060886522844,
#     "course": 27.727062225341797,
#     "latitude": 40.76130857285171,
#     "longitude": -73.96254106451933,
#     "geohash": "dr5ruuq5gfsh",
#     "speed": 6.920000076293945,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "037.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 41
# Message Key: 3447c230e1aa49c1a494353f3fb467b2
# Message Value:
#   {
#     "index": 35,
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796343",
#     "offset": 38.7677702566351,
#     "course": 36.619529724121094,
#     "latitude": 40.69583299385881,
#     "longitude": -73.92404928380162,
#     "geohash": "dr5rtb6nkv1e",
#     "speed": 7.199999809265137,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov",
#     "t": "037.7"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 42
# Message Key: acab191b4cd34be890ab5e446b354cae
# Message Value:
#   {
#     "index": 38,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882546",
#     "offset": 41.525060886522844,
#     "course": 24.04581642150879,
#     "latitude": 40.76112555160191,
#     "longitude": -73.96265838794845,
#     "geohash": "dr5ruuq4c0s8",
#     "speed": 8.220000267028809,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 43
# Message Key: fa24d0bc19e64d2d98d548818377cfb6
# Message Value:
#   {
#     "index": 41,
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796340",
#     "offset": 41.7677702566351,
#     "course": 36.619529724121094,
#     "latitude": 40.69567495232888,
#     "longitude": -73.92420359639651,
#     "geohash": "dr5rtb6j3pws",
#     "speed": 7.96999979019165,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 44
# Message Key: 34142d0462c54d62b4c39ae0d6e6fa92
# Message Value:
#   {
#     "index": 37,
#     "id": null,
#     "ride_id": "53a79e2d25ebf0ea29b4f4dea39496b3",
#     "uuid": "080ab7e8d1bb4ac4bcf6b32bec82607d",
#     "timestamp": "1970-01-01 00:24:50.366761",
#     "offset": 42.02312381072749,
#     "course": 81.2109375,
#     "latitude": 40.62653339471726,
#     "longitude": -73.97117282270824,
#     "geohash": "dr5rhezfdwxz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "b0c74075-f0c0-470a-a2bf-c627f91b30b6.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 45
# Message Key: 13a09513e18b4f068f03ce12d6b659fe
# Message Value:
#   {
#     "index": 43,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320412",
#     "offset": 42.07791252955665,
#     "course": 158.5546875,
#     "latitude": 40.67892904862825,
#     "longitude": -73.82060819312355,
#     "geohash": "dr5x2jm7zjuz",
#     "speed": 0.8700000047683716,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 46
# Message Key: ffe559ba79eb499582d50f7a4379c9ec
# Message Value:
#   {
#     "index": 39,
#     "id": "723d9d0fa092b5ca1ffce252012836de",
#     "ride_id": "4f9ca8ae06a03858267820b3ad458fce",
#     "uuid": "459eeb9143d04df3b27397678047be20",
#     "timestamp": "1970-01-01 00:25:04.355834",
#     "offset": 42.14024503805739,
#     "course": 114.2578125,
#     "latitude": 40.87394186299375,
#     "longitude": -73.85583590723002,
#     "geohash": "dr72x2ggfr10",
#     "speed": 10.5,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "78665bfb-b7d8-464a-a840-8a967d44e187.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 47
# Message Key: 3c1a88072af8494099a3f9209caf822f
# Message Value:
#   {
#     "index": 40,
#     "id": "097ec0c2d59a23b76b4942bd8d9a7a77",
#     "ride_id": "9cd83b5a569a73d2e596888b6a6ad6ad",
#     "uuid": "a8fab740fe074ef1acc7d4c940398ce8",
#     "timestamp": "1970-01-01 00:25:04.070072",
#     "offset": 42.16329633059419,
#     "course": 318.1640625,
#     "latitude": 37.525225826574044,
#     "longitude": -122.2686281149483,
#     "geohash": "9q9j3xq8q3ng",
#     "speed": 26.190000534057617,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "65c58848-8a31-4b1c-bfef-8643378fec25.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 48
# Message Key: 7cee6e83cabb46389ae7a7eb907b2adf
# Message Value:
#   {
#     "index": 42,
#     "id": "c44516bd325cb60548b431b4d6409dde",
#     "ride_id": "b063cb65cd8446b83b4a09d4db2646c8",
#     "uuid": "c6608d4cb9224aa3a0763a835e6c8788",
#     "timestamp": "1970-01-01 00:25:06.796339",
#     "offset": 42.7677702566351,
#     "course": 36.619529724121094,
#     "latitude": 40.69560697227848,
#     "longitude": -73.92426997248121,
#     "geohash": "dr5rtb3vpdvp",
#     "speed": 10.039999961853027,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "0d4d27dc-360b-4bb2-9b0c-bf84be964785.mov",
#     "t": "041.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 49
# Message Key: a720a4e1117449cfa30166f35c1b1de2
# Message Value:
#   {
#     "index": 1,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320453",
#     "offset": 1.0779125295566454,
#     "course": 158.203125,
#     "latitude": 40.677641336844,
#     "longitude": -73.81793000742218,
#     "geohash": "dr5x2jpkmtcy",
#     "speed": 2.119999885559082,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 50
# Message Key: 1b4d97f28c2a4395b58ccbca4f0c7bf1
# Message Value:
#   {
#     "index": 0,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.76287002542555,
#     "longitude": -73.96194855681718,
#     "geohash": "dr5ruuwscttz",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 51
# Message Key: 2a413a2df1b546b0a8081dc3403096bb
# Message Value:
#   {
#     "index": 2,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882583",
#     "offset": 4.5250608865228426,
#     "course": 299.619140625,
#     "latitude": 40.76287038067684,
#     "longitude": -73.96194937863832,
#     "geohash": "dr5ruuwsctv3",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "004.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 52
# Message Key: 8725358b5788444292b97308ae70fb09
# Message Value:
#   {
#     "index": 3,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320449",
#     "offset": 5.077912529556645,
#     "course": 159.9609375,
#     "latitude": 40.67788281947438,
#     "longitude": -73.81804710260948,
#     "geohash": "dr5x2jpmfffw",
#     "speed": 11.75,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "004.5"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 53
# Message Key: 026066917c2d4883ada8acd5aff0b6b8
# Message Value:
#   {
#     "index": 5,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320446",
#     "offset": 8.077912529556645,
#     "course": 159.609375,
#     "latitude": 40.67819106396351,
#     "longitude": -73.81819261244854,
#     "geohash": "dr5x2jppxkqj",
#     "speed": 13.149999618530273,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "007.8"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 54
# Message Key: 1d71153b4a114bcda1b7a6c8b88338ef
# Message Value:
#   {
#     "index": 4,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882579",
#     "offset": 8.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.76286948909357,
#     "longitude": -73.96194731609269,
#     "geohash": "dr5ruuwsctwg",
#     "speed": 0.0,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "007.8"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 55
# Message Key: 296df6948cb543d9aebb6f4bbd51e113
# Message Value:
#   {
#     "index": 7,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320443",
#     "offset": 11.077912529556645,
#     "course": 159.609375,
#     "latitude": 40.678531159684695,
#     "longitude": -73.81836075342616,
#     "geohash": "dr5x2jr1eebd",
#     "speed": 13.800000190734863,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 56
# Message Key: 08ad6b36cd4046aeb0e561425578224f
# Message Value:
#   {
#     "index": 6,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882576",
#     "offset": 11.525060886522843,
#     "course": 299.619140625,
#     "latitude": 40.762862338920996,
#     "longitude": -73.96193077522916,
#     "geohash": "dr5ruuwsfh71",
#     "speed": 1.5099999904632568,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 57
# Message Key: b9defa4021554256afaa4b057595d344
# Message Value:
#   {
#     "index": 8,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.077912529556645,
#     "course": 161.015625,
#     "latitude": 40.678637903221585,
#     "longitude": -73.81842395297608,
#     "geohash": "dr5x2jr44p9x",
#     "speed": 14.210000038146973,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-locations
#   Partition: 0
#   Offset: 58
# Message Key: 3664e5aaa2fd421d8657254136a4dc01
# Message Value:
#   {
#     "index": 10,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320439",
#     "offset": 15.077912529556645,
#     "course": 161.3671875,
#     "latitude": 40.67896198950771,
#     "longitude": -73.8185656909587,
#     "geohash": "dr5x2jqunspu",
#     "speed": 10.90999984741211,
#     "accuracy": 10.0,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "014.9"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 0
# Message Key: d537da024ac5452d9559e7b67fb6d608
# Message Value:
#   {
#     "index": 0,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.8220608865228429,
#     "x": -0.994,
#     "y": 0.045,
#     "z": -0.036000000000000004,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 1
# Message Key: de63c645827a4101bf13863a10fa5bb9
# Message Value:
#   {
#     "index": 1,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.8420608865228429,
#     "x": -0.998,
#     "y": 0.046,
#     "z": -0.04,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 2
# Message Key: d92ed0873a0b4c2bb23d4725b573bbcf
# Message Value:
#   {
#     "index": 2,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.862060886522843,
#     "x": -0.999,
#     "y": 0.047,
#     "z": -0.036000000000000004,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 3
# Message Key: abc8d632e981462eaa12077815491f87
# Message Value:
#   {
#     "index": 3,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.882060886522843,
#     "x": -0.999,
#     "y": 0.045,
#     "z": -0.034,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 4
# Message Key: f6a15864a9e54348a93de000eadc5e3e
# Message Value:
#   {
#     "index": 4,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.9020608865228429,
#     "x": -0.999,
#     "y": 0.048,
#     "z": -0.033,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 5
# Message Key: 4c64741d5ab14c52935ef1a6870b6896
# Message Value:
#   {
#     "index": 5,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.9220608865228429,
#     "x": -0.997,
#     "y": 0.046,
#     "z": -0.034,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 6
# Message Key: f730c107b5424601bd2da160fee9f72c
# Message Value:
#   {
#     "index": 6,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.9420608865228429,
#     "x": -1.0,
#     "y": 0.048,
#     "z": -0.031,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 7
# Message Key: 2ee65c84425f45ccb1fd795b3fe732d4
# Message Value:
#   {
#     "index": 7,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.9630608865228429,
#     "x": -0.995,
#     "y": 0.05,
#     "z": -0.035,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 8
# Message Key: 0dbb332f50984e109fdf0eaed9b5e0de
# Message Value:
#   {
#     "index": 8,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 0.983060886522843,
#     "x": -1.0010000000000001,
#     "y": 0.049,
#     "z": -0.038,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 9
# Message Key: 228ad3f9716a42ef897fd56face0c2a6
# Message Value:
#   {
#     "index": 9,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.003060886522843,
#     "x": -0.994,
#     "y": 0.046,
#     "z": -0.034,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 10
# Message Key: c15b8ca8d31641a48c705519d864c500
# Message Value:
#   {
#     "index": 10,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.023060886522843,
#     "x": -0.999,
#     "y": 0.047,
#     "z": -0.033,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 11
# Message Key: 7626ac7d9f61401c94d8c6d3ad823cb6
# Message Value:
#   {
#     "index": 36,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320453",
#     "offset": 1.0239125295566454,
#     "x": -0.983,
#     "y": -0.053,
#     "z": -0.132,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 12
# Message Key: f377762e2e02437d866bd9bfc3007de4
# Message Value:
#   {
#     "index": 11,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.043060886522843,
#     "x": -0.995,
#     "y": 0.045,
#     "z": -0.032,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 13
# Message Key: dc8cc7735e004227863d0297d729c0b3
# Message Value:
#   {
#     "index": 37,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320453",
#     "offset": 1.0439125295566454,
#     "x": -0.975,
#     "y": -0.049,
#     "z": -0.139,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 14
# Message Key: 7b3d8dcdfd99445989f7cc25893f54a1
# Message Value:
#   {
#     "index": 38,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320453",
#     "offset": 1.0629125295566453,
#     "x": -0.98,
#     "y": -0.06,
#     "z": -0.155,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 15
# Message Key: a405c32070f34bdfaee2da6da74a6b0a
# Message Value:
#   {
#     "index": 12,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.0630608865228428,
#     "x": -0.996,
#     "y": 0.043000000000000003,
#     "z": -0.034,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 16
# Message Key: 26c52d93a2e14f4d8c849a7585e57d62
# Message Value:
#   {
#     "index": 39,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320452",
#     "offset": 1.0829125295566453,
#     "x": -0.974,
#     "y": -0.044,
#     "z": -0.158,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 17
# Message Key: 61897484d75f41da912ba1d0db4665ee
# Message Value:
#   {
#     "index": 13,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.0830608865228428,
#     "x": -0.998,
#     "y": 0.049,
#     "z": -0.035,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 18
# Message Key: 29508edeb1ac4c3fbfe141ac574b6d73
# Message Value:
#   {
#     "index": 40,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320452",
#     "offset": 1.1019125295566454,
#     "x": -0.985,
#     "y": -0.033,
#     "z": -0.17500000000000002,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "000.0"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 19
# Message Key: 39d8c5f324f947c681cee6d9d1988a7c
# Message Value:
#   {
#     "index": 14,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882586",
#     "offset": 1.1030608865228428,
#     "x": -0.996,
#     "y": 0.046,
#     "z": -0.038,
#     "timelapse": false,
# ...
# Message Value:
#   {
#     "index": 401,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 11.919912529556646,
#     "x": -1.033,
#     "y": 0.0,
#     "z": 0.014,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 388
# Message Key: c141acbf40c94978b4d5030e92b91ff9
# Message Value:
#   {
#     "index": 320,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 11.929060886522842,
#     "x": -1.0110000000000001,
#     "y": 0.039,
#     "z": -0.098,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 389
# Message Key: cdb8adc0193e45ce88a5589fb342c3d1
# Message Value:
#   {
#     "index": 402,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 11.939912529556645,
#     "x": -1.0050000000000001,
#     "y": 0.081,
#     "z": -0.032,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 390
# Message Key: 649283aad4504a19952b548bb0ed419d
# Message Value:
#   {
#     "index": 321,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 11.949060886522844,
#     "x": -0.993,
#     "y": 0.046,
#     "z": -0.08700000000000001,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 391
# Message Key: 8b4c49a423ff44b2b5a031bde60024fc
# Message Value:
#   {
#     "index": 403,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 11.958912529556645,
#     "x": -1.031,
#     "y": 0.07,
#     "z": -0.044,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 392
# Message Key: 338272623e99448da5944095ccf63d60
# Message Value:
#   {
#     "index": 322,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 11.969060886522843,
#     "x": -1.0030000000000001,
#     "y": 0.035,
#     "z": -0.099,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 393
# Message Key: c7cfa96c207948669594e2454e180600
# Message Value:
#   {
#     "index": 404,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 11.978912529556645,
#     "x": -0.9570000000000001,
#     "y": -0.017,
#     "z": -0.033,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 394
# Message Key: f37b327e595649b48c5ef7832947be70
# Message Value:
#   {
#     "index": 323,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 11.989060886522843,
#     "x": -1.0190000000000001,
#     "y": 0.048,
#     "z": -0.099,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 395
# Message Key: f4a9abdb2d774f0c919a2bce4470fe74
# Message Value:
#   {
#     "index": 405,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 11.997912529556645,
#     "x": -1.0190000000000001,
#     "y": 0.07,
#     "z": -0.022,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 396
# Message Key: aa6e05fa08624f238bf71f23b310511a
# Message Value:
#   {
#     "index": 324,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.009060886522843,
#     "x": -0.972,
#     "y": 0.056,
#     "z": -0.093,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 397
# Message Key: f1b3e6af0d554e4a98b1f1e3c4f353cf
# Message Value:
#   {
#     "index": 406,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.017912529556645,
#     "x": -1.014,
#     "y": -0.002,
#     "z": -0.024,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 398
# Message Key: 4162cd34574448239a264c1bbb1227c5
# Message Value:
#   {
#     "index": 325,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.029060886522844,
#     "x": -1.027,
#     "y": 0.057,
#     "z": -0.08700000000000001,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 399
# Message Key: b0ed29bfbee4428aab034782dbad55ec
# Message Value:
#   {
#     "index": 407,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.036912529556645,
#     "x": -0.9410000000000001,
#     "y": -0.017,
#     "z": -0.011,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 400
# Message Key: 792a51ae462d4daaa18a23caa1c1c579
# Message Value:
#   {
#     "index": 326,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.049060886522843,
#     "x": -0.972,
#     "y": 0.051000000000000004,
#     "z": -0.079,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 401
# Message Key: c6632dcbc4444179a4b3ca64a9438778
# Message Value:
#   {
#     "index": 408,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.056912529556644,
#     "x": -0.978,
#     "y": -0.02,
#     "z": -0.003,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 402
# Message Key: 22b2e8a0545e40ceba530806512b0615
# Message Value:
#   {
#     "index": 327,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.069060886522843,
#     "x": -1.0030000000000001,
#     "y": 0.055,
#     "z": -0.093,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 403
# Message Key: 0d0dd6579a654c3eb1970b49e560911e
# Message Value:
#   {
#     "index": 409,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320442",
#     "offset": 12.075912529556645,
#     "x": -0.904,
#     "y": 0.058,
#     "z": 0.056,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 404
# Message Key: 5f12b11181f14ac1818e6bcb2c9fd02f
# Message Value:
#   {
#     "index": 328,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.089060886522843,
#     "x": -0.976,
#     "y": 0.081,
#     "z": -0.093,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 405
# Message Key: 4c8e395b65e04cba9e92d00efa026a63
# Message Value:
#   {
#     "index": 410,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.095912529556644,
#     "x": -0.932,
#     "y": 0.089,
#     "z": -0.001,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 406
# Message Key: 3c57304c064444749a76084ccc4ef202
# Message Value:
#   {
#     "index": 329,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.109060886522844,
#     "x": -0.985,
#     "y": 0.061,
#     "z": -0.091,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 407
# Message Key: ab530b536808457391c52d78d4f35d65
# Message Value:
#   {
#     "index": 411,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.115912529556645,
#     "x": -0.848,
#     "y": 0.077,
#     "z": 0.033,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 408
# Message Key: d7857fb9dd244c1686940d19e6520415
# Message Value:
#   {
#     "index": 330,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.129060886522844,
#     "x": -1.004,
#     "y": 0.065,
#     "z": -0.067,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 409
# Message Key: 9f73c66d6b45429db7d2b99679635d6d
# Message Value:
#   {
#     "index": 412,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.134912529556646,
#     "x": -1.002,
#     "y": -0.03,
#     "z": 0.054,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 410
# Message Key: faf7b96165944c8b9ad65c58ef2b015e
# Message Value:
#   {
#     "index": 331,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.150060886522843,
#     "x": -0.9530000000000001,
#     "y": 0.065,
#     "z": -0.07100000000000001,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 411
# Message Key: 1d91a2233d1648588f2f6fbcdf0060d0
# Message Value:
#   {
#     "index": 413,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.154912529556645,
#     "x": -0.935,
#     "y": 0.03,
#     "z": 0.019,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 412
# Message Key: 026a75d886e741558aaedd144f45395c
# Message Value:
#   {
#     "index": 332,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.170060886522844,
#     "x": -1.012,
#     "y": 0.076,
#     "z": -0.078,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 413
# Message Key: df4d3f9e01b642cb8d6432aabb90757f
# Message Value:
#   {
#     "index": 414,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.173912529556645,
#     "x": -1.01,
#     "y": -0.15,
#     "z": 0.058,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 414
# Message Key: b30d21eb66464ecf81f98640680418f4
# Message Value:
#   {
#     "index": 333,
#     "id": "58682c5d48cad9d9e103431d773615bf",
#     "ride_id": "c9a2b46c9aa515b632eddc45c4868482",
#     "uuid": "19b9aa10588646b3bf22c9b4865a7995",
#     "timestamp": "1970-01-01 00:25:03.882575",
#     "offset": 12.190060886522843,
#     "x": -0.9560000000000001,
#     "y": 0.068,
#     "z": -0.073,
#     "timelapse": false,
#     "filename": "e2f795a7-6a7d-4500-b5d7-4569de996811.mov",
#     "t": "010.6"
#   }
#
# Message metadata:
#   Topic: PayneBarbara-accelerations
#   Partition: 0
#   Offset: 415
# Message Key: 6c96d5b14342423fa2f756a14f25e7e1
# Message Value:
#   {
#     "index": 415,
#     "id": "85c61911b7fe2ced1000c33c9e932706",
#     "ride_id": "6760ffa3f41908695d1405b776c3e8d5",
#     "uuid": "dad7eae44e784b549c8c5a3aa051a8c7",
#     "timestamp": "1970-01-01 00:25:07.320441",
#     "offset": 12.193912529556645,
#     "x": -0.963,
#     "y": -0.022,
#     "z": 0.04,
#     "timelapse": false,
#     "filename": "d745b92f-aefd-467d-9121-7a71308e8d6d.mov",
#     "t": "010.6"
#   }
#
# STOPPING MESSAGE CONSUMER

# %% [markdown]
# Close the consumer, waiting indefinitely for any needed cleanup.

# %%
consumer.close()
